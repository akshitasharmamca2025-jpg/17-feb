# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitasharmamca2025-jpg/17-feb/blob/main/line%20chart%20of%20monthos%20and%20sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Monthly sales data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct']
sales = [120, 150, 170, 160, 180, 200, 210, 190, 220, 230]

# Create the line chart
plt.figure(figsize=(10, 6))
plt.plot(months, sales, marker='o', linestyle='-', color='skyblue')

# Add title and labels
plt.title('Monthly Sales Trend', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales', fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
